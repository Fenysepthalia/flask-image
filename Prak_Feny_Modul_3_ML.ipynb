# %% [markdown]
# <a href="https://colab.research.google.com/github/Fenysepthalia/flask-image/blob/main/Prak_Feny_Modul_3_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Soal Praktikum Overfitting Handling #1**

# %% [markdown]
# ## Kegiatan 1 **(Individu)**
# 70 poin

# %% [markdown]
# **Peraturan :**
# * Tidak boleh ada error dalam kode program
# * Dalam modul ini tidak diperbolehkan menggunakan teknik transfer learning dari pretrain model baik yang telah dibangun sendiri atau anda dapatkan dari sumber lain (tensorflow, keras, dan sebagainya)
# * Perhatikan langkah demi langkah yang diperintahkan dalam kegiatan ini

# %% [markdown]
# ### Pengenalan tugas kegiatan 1

# %% [markdown]
# Dataset yang akan anda gunakan dalam kegiatan ini adalah dataset [Rock Paper Scissors](https://www.kaggle.com/drgfreeman/rockpaperscissors).  Demi mempermudah anda dalam mengerjakan modul ini maka akan sangat disarankan untuk menggunakan [google colab](https://colab.research.google.com/). Anda dapat menggunakan google colab untuk mendownload langsung dataset dari kaggle dan menyimpannya dalam google drive anda. Untuk kenyamanan dan ruang kerja yang besar akan lebih baik anda menggunakan email kampus untuk menyimpan dataset yang anda gunakan. Perhatikan langkah berikut untuk melakukan setting environment anda.

# %% [markdown]
# ### 1. Initial process

# %% [markdown]
# * Mount drive terlebih dahulu
#
# * Untuk dapat mengakses dataset ini anda diharuskan memiliki akun kaggle. Jika belum memilikinya buat satu akun pribadi.
#
# * Download kaggle API.json kemudian upload dalam google drive anda.
#
# * Ubah lokasi direktori kerja anda ke direktori dimana anda menyimpan kaggle.json
#
# * Buka laman dataset kemudian Copy API Command.
#
# * Jalankan perintah untuk mendownload dataset dari kaggle menggunakan google colab.
#
# * Gunakan tutorial berikut untuk lebih jelasnya : [Fetch Kaggle Dataset into Google Colab](https://medium.com/analytics-vidhya/how-to-fetch-kaggle-datasets-into-google-colab-ea682569851a)
#
# * Untuk selanjutnya pahami code dibawah dengan baik.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Definisikan path kaggle json
# Sesuaikan dengan path anda
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/PrakML"

# %%
# Ubah lokasi direktori kerja
# Sesuaikan dengan path anda
# %cd /content/drive/MyDrive/PrakML
# Out:
# /content/drive/MyDrive/PrakML

# %%
# Cek apakah api sudah terbaca oleh sistem
# !ls
# Out:
# Dataset      README_rpc-cv-images.txt  test   valid
# kaggle.json  rps-cv-images	       train

# %% [markdown]
# * Paste API Command dari kaggle dataset yang telah anda copy sebelumnya dan tambahkan tanda seru didepannya.
# * Pastikan anda menggunakan akun google dari kampus untuk mendapatkan storage penyimpanan unlimited.
# * Lebih disarankan untuk menggunakan google colab karena proses download data lebih cepat dan stabil daripada download manual dan menggunakan jupyter notebook.

# %%
# !kaggle datasets download -d drgfreeman/rockpaperscissors
# Out:
# Downloading rockpaperscissors.zip to /content/drive/MyDrive/PrakML
#  99% 303M/306M [00:02<00:00, 99.2MB/s]
# 100% 306M/306M [00:02<00:00, 110MB/s]

# %%
# Cek isi direktori kerja dan memastikan dataset telah berhasil didownload.
# !ls
# Out:
# kaggle.json  rockpaperscissors.zip

# %%
# Ekstrak file dataset dan hapus file zip dataset agar tidak memakan banyak tempat.
# !unzip \*.zip &> /dev/null && rm *.zip

# %%
# Cek isi direktori kerja untuk memastikan dataset telah berhasil diekstrak.
# !ls
# Out:
# kaggle.json  paper  README_rpc-cv-images.txt  rock  rps-cv-images  scissors

# %% [markdown]
# Buat folder baru bernama `dataset` dan memindahkan folder `paper, rock, scissors` kedalam folder `dataset`. Selanjutnya, lakukan splitting dataset menjadi 3 bagian `train, test, val` dan simpan ketiga folder tersebut diluar folder `dataset`. Data `train dan val` akan digunakan ketika anda melakukan training model. Dan data `test` akan anda gunakan ketika anda melakukan prediksi unseen data menggunakan model yang telah anda latih.
#
# *Ingat google colab juga menerima command berbasis linux.*

# %%
from os import mkdir

mkdir ('Dataset')

# %%
ls
# Out:
# Dataset/     paper/                    rock/           scissors/
# kaggle.json  README_rpc-cv-images.txt  rps-cv-images/

# %%
import shutil, sys

shutil.move("/content/drive/My Drive/PrakML/paper", "/content/drive/My Drive/PrakML/Dataset") 
shutil.move("/content/drive/My Drive/PrakML/rock", "/content/drive/My Drive/PrakML/Dataset") 
shutil.move("/content/drive/My Drive/PrakML/scissors", "/content/drive/My Drive/PrakML/Dataset")
# Out:
# '/content/drive/My Drive/PrakML/Dataset/scissors'

# %%
# TULIS KODE ANDA DISINI

# %rm -rf test
# %rm -rf train
# %rm -rf valid

# %%
import numpy as np
import pandas as pd
import os
from shutil import copyfile

TRAIN_DIR = "/content/drive/My Drive/PrakML/train/"
VALID_DIR ="/content/drive/My Drive/PrakML/valid/"
TEST_DIR ="/content/drive/My Drive/PrakML/test/"

os.mkdir(TRAIN_DIR)
os.mkdir(VALID_DIR)
os.mkdir(TEST_DIR)

for label in ['paper', 'rock', 'scissors']:
    os.mkdir(TRAIN_DIR+label)
    os.mkdir(VALID_DIR+label)
    os.mkdir(TEST_DIR+label)

# %%
import random

def train_valid_test_split(source, train_dir, valid_dir, test_dir,train_size, valid_size, test_size):
    # get files
    files = []
    for filename in os.listdir(source):
        file = source + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
    
    # train valid split
    train_size = int(len(files) * (1-(valid_size + train_size)))
    valid_size = int(len(files) * (1-(valid_size + test_size)))
    test_size = int(len(files) * (1-train_size))
  
    # shuffle the dataset
    shuffled_files = random.sample(files, len(files))
    
    train_set = shuffled_files[train_size:valid_size]
    valid_set = shuffled_files[valid_size:]
    test_set = shuffled_files[:train_size]
    
    for filename in train_set:
        filepath = source + filename
        destination = train_dir + filename
        copyfile(filepath, destination)
        
    for filename in valid_set:
        filepath = source + filename
        destination = valid_dir + filename
        copyfile(filepath, destination)
    
    for filename in test_set:
        filepath = source + filename
        destination = test_dir + filename
        copyfile(filepath, destination)

SOURCE = "/content/drive/My Drive/PrakML/Dataset/"

for label in ['paper', 'rock', 'scissors']:
    print(label)
    train_valid_test_split(SOURCE+label+'/',  TRAIN_DIR +label+'/', VALID_DIR +label+'/', TEST_DIR +label+'/', train_size=0.8, valid_size=0.19, test_size=0.01)
    print('Total images: ', len(os.listdir(SOURCE +label+'/')))
    print('Training: ', len(os.listdir(TRAIN_DIR +label+'/')))
    print('Validation: ', len(os.listdir(VALID_DIR +label+'/')))
    print('Testing: ', len(os.listdir(TEST_DIR +label+'/')))
    print()
# Out:
# paper
# Total images:  712
# Training:  562
# Validation:  143
# Testing:  7
#
# rock
# Total images:  726
# Training:  573
# Validation:  146
# Testing:  7
#
# scissors
# Total images:  750
# Training:  593
# Validation:  150
# Testing:  7

# %% [markdown]
# ### 2. Data Preprocessing

# %% [markdown]
# Kita anggap dataset yang kita miliki merupakan dataset yang telah bersih dan siap digunakan untuk proses training model. Namun agar data yang kita miliki dapat diproses oleh model maka kita perlu melakukan sedikit proses augmentasi sederhana.
#
# **NOTE :** Penjelasan augmentasi secara detail akan dibahas pada modul selanjutnya. Disini kita akan mengunakan augmentasi sederhana saja seperti resize, flip dan rotation.

# %% [markdown]
# Lakukan proses agumentasi sederhana pada dataset anda menggunakan `ImageDataGenerator` dengan ketentuan melakukan proses seperti berikut :
#
# * Resize
# * Rescaling
# * Color Mode
# * Shuffle
# * Class Mode
#
# Terapkan semua proses diatas pada data `train, test dan validation`.

# %%
from keras.preprocessing.image import ImageDataGenerator

train_generator = ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip = True, #bolak balik image secara vertika, dan true = on
    vertical_flip = True,
    rotation_range = 90,
    height_shift_range = 0.2,
    width_shift_range = 0.2,
    zoom_range = 0.2
)

test_generator = ImageDataGenerator(
    rescale = 1./255,
    validation_split = 0.7
)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_dir = '/content/drive/My Drive/PrakML/train'
train_datagen = ImageDataGenerator(
      rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    color_mode='rgb',
    class_mode = 'categorical',
    shuffle=True,
)
# Out:
# Found 1728 images belonging to 3 classes.

# %%
from keras.preprocessing.image import ImageDataGenerator

test_dir = '/content/drive/My Drive/PrakML/test'
train_datagen = ImageDataGenerator(
      rescale=1./255)

test_generator = train_datagen.flow_from_directory(
    test_dir,
    target_size = (150, 150),
    color_mode='rgb',
    class_mode = 'categorical',
    shuffle=True,
)
# Out:
# Found 21 images belonging to 3 classes.

# %%
from keras.preprocessing.image import ImageDataGenerator

valid_dir = '/content/drive/My Drive/PrakML/valid'
train_datagen = ImageDataGenerator(
      rescale=1./255)

valid_generator = train_datagen.flow_from_directory(
    valid_dir,
    target_size = (150, 150),
    color_mode='rgb',
    class_mode = 'categorical',
    shuffle=True,
)
# Out:
# Found 439 images belonging to 3 classes.

# %% [markdown]
# ### 3. Definisikan Model CNN

# %% [markdown]
# Bangun model CNN dan lakukan evaluasi sesuai kriteria **WAJIB** berikut:
#
# * Menerapkan proses Convolution
# * Menerapkan proses Pooling
# * Menerapkan Dropout
# * Menerpakan BatchNormalization
# * Evaluasi model menggunakan grafik loss dan accuracy
# * Evaluasi menggunakan classification report
# * Evaluasi menggunakan confusion matrix
# * Pastikan nilai akurasi model > 80%
# * Mendefinisikan minimal 100 epoch untuk masing-masing model
# * Melakukan prediksi minimal 15 gambar acak yang dapat mewakili seluruh kelas
# * Menampilkan input gambar yang di prediksi beserta label hasil prediksi, nilai akurasi prediksi, dan lama waktu prediksi dalam sebuah plot. (15 gambar ditampilkan dalam 1 plot)
# * Save model dalam file `json` dan simpan bobot dalam file `HDF5`
# * Pastikan model anda dapat memprediksi unseen data dengan benar.

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization
import tensorflow as tf

inputs = tf.keras.Input(shape = (150, 150, 3))
x = tf.keras.layers.Conv2D(filters = 16, kernel_size = (3, 3), activation = 'relu')(inputs)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3), activation = 'relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.Conv2D(filters = 128, kernel_size = (3, 3), activation = 'relu')(x)
x = tf.keras.layers.MaxPool2D()(x)
x = tf.keras.layers.GlobalMaxPool2D()(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(512, activation = 'relu')(x)
outputs = tf.keras.layers.Dense(3, activation = 'softmax')(x)

model = tf.keras.Model(inputs = inputs, outputs = outputs)


model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)


history = model.fit(
    train_generator,
    validation_data = valid_generator,
    epochs = 100,
    callbacks = [
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=40,
            verbose=1, 
            mode='auto',
            cooldown=1
        )
    ]
)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 11s 188ms/step - loss: 0.7396 - accuracy: 0.6678 - val_loss: 0.8561 - val_accuracy: 0.8610 - lr: 0.0010
# Epoch 2/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.2955 - accuracy: 0.9062 - val_loss: 0.6206 - val_accuracy: 0.8200 - lr: 0.0010
# Epoch 3/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.2032 - accuracy: 0.9340 - val_loss: 0.6450 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 4/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.1436 - accuracy: 0.9572 - val_loss: 0.3451 - val_accuracy: 0.9431 - lr: 0.0010
# Epoch 5/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.1676 - accuracy: 0.9416 - val_loss: 0.1921 - val_accuracy: 0.9795 - lr: 0.0010
# Epoch 6/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.1130 - accuracy: 0.9589 - val_loss: 0.3027 - val_accuracy: 0.8747 - lr: 0.0010
# Epoch 7/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.1201 - accuracy: 0.9630 - val_loss: 0.1642 - val_accuracy: 0.9590 - lr: 0.0010
# Epoch 8/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0978 - accuracy: 0.9716 - val_loss: 0.0274 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 9/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0915 - accuracy: 0.9728 - val_loss: 0.0194 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 10/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0826 - accuracy: 0.9774 - val_loss: 0.0218 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 11/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0675 - accuracy: 0.9797 - val_loss: 0.0880 - val_accuracy: 0.9727 - lr: 0.0010
# Epoch 12/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.1261 - accuracy: 0.9618 - val_loss: 0.0528 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 13/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0689 - accuracy: 0.9751 - val_loss: 0.0189 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 14/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0669 - accuracy: 0.9774 - val_loss: 0.0882 - val_accuracy: 0.9749 - lr: 0.0010
# Epoch 15/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0641 - accuracy: 0.9797 - val_loss: 0.0302 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 16/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0624 - accuracy: 0.9797 - val_loss: 0.0150 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 17/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0452 - accuracy: 0.9838 - val_loss: 0.0144 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 18/100
# 54/54 [==============================] - 9s 174ms/step - loss: 0.0594 - accuracy: 0.9803 - val_loss: 0.0207 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 19/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0650 - accuracy: 0.9815 - val_loss: 0.0103 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 20/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.0530 - accuracy: 0.9815 - val_loss: 0.0132 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 21/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.0436 - accuracy: 0.9861 - val_loss: 0.0296 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 22/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.0420 - accuracy: 0.9855 - val_loss: 0.0210 - val_accuracy: 0.9909 - lr: 0.0010
# Epoch 23/100
# 54/54 [==============================] - 10s 183ms/step - loss: 0.0448 - accuracy: 0.9844 - val_loss: 0.0047 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/100
# 54/54 [==============================] - 10s 182ms/step - loss: 0.0397 - accuracy: 0.9878 - val_loss: 0.0203 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 25/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0380 - accuracy: 0.9873 - val_loss: 0.0137 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 26/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0542 - accuracy: 0.9832 - val_loss: 0.0503 - val_accuracy: 0.9727 - lr: 0.0010
# Epoch 27/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0408 - accuracy: 0.9838 - val_loss: 0.0283 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 28/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0350 - accuracy: 0.9913 - val_loss: 0.0099 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 29/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0405 - accuracy: 0.9844 - val_loss: 0.0077 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 30/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0430 - accuracy: 0.9850 - val_loss: 0.0826 - val_accuracy: 0.9681 - lr: 0.0010
# Epoch 31/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0403 - accuracy: 0.9873 - val_loss: 0.0270 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 32/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0251 - accuracy: 0.9907 - val_loss: 0.0107 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 33/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0303 - accuracy: 0.9890 - val_loss: 0.0255 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 34/100
# 54/54 [==============================] - 9s 174ms/step - loss: 0.0370 - accuracy: 0.9884 - val_loss: 0.0073 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 35/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0160 - accuracy: 0.9925 - val_loss: 0.0087 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 36/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0282 - accuracy: 0.9896 - val_loss: 0.0277 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 37/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0258 - accuracy: 0.9936 - val_loss: 0.0093 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 38/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0276 - accuracy: 0.9907 - val_loss: 0.0164 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 39/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0170 - accuracy: 0.9936 - val_loss: 0.0070 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 40/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0237 - accuracy: 0.9936 - val_loss: 0.0128 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 41/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0366 - accuracy: 0.9861 - val_loss: 0.0072 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 42/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0221 - accuracy: 0.9919 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 43/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0203 - accuracy: 0.9959 - val_loss: 0.0123 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 44/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0291 - accuracy: 0.9907 - val_loss: 0.0116 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 45/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.0133 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 46/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0126 - accuracy: 0.9954 - val_loss: 0.0266 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 47/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0242 - accuracy: 0.9925 - val_loss: 0.0087 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 48/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0319 - accuracy: 0.9896 - val_loss: 0.0082 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 49/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0334 - accuracy: 0.9878 - val_loss: 0.0107 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 50/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 51/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0373 - accuracy: 0.9913 - val_loss: 0.0369 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 52/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0232 - accuracy: 0.9919 - val_loss: 0.0512 - val_accuracy: 0.9863 - lr: 0.0010
# Epoch 53/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0290 - accuracy: 0.9902 - val_loss: 0.0236 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 54/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 0.0276 - val_accuracy: 0.9909 - lr: 0.0010
# Epoch 55/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0352 - accuracy: 0.9919 - val_loss: 0.0878 - val_accuracy: 0.9704 - lr: 0.0010
# Epoch 56/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0521 - accuracy: 0.9850 - val_loss: 0.0122 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 57/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0332 - accuracy: 0.9861 - val_loss: 0.0103 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 58/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0224 - accuracy: 0.9919 - val_loss: 0.0023 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 59/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0241 - accuracy: 0.9936 - val_loss: 0.0165 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 60/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0320 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 61/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0138 - accuracy: 0.9948 - val_loss: 0.0032 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 62/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0177 - accuracy: 0.9919 - val_loss: 0.0042 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 63/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0266 - accuracy: 0.9925 - val_loss: 0.0135 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 64/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0269 - accuracy: 0.9896 - val_loss: 0.0157 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 65/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0334 - accuracy: 0.9884 - val_loss: 0.0105 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 66/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.0040 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 67/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.6825 - val_accuracy: 0.7790 - lr: 0.0010
# Epoch 68/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0341 - accuracy: 0.9907 - val_loss: 0.0324 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 69/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.0164 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 70/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0197 - accuracy: 0.9948 - val_loss: 0.0229 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 71/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0234 - accuracy: 0.9913 - val_loss: 0.0672 - val_accuracy: 0.9818 - lr: 0.0010
# Epoch 72/100
# 54/54 [==============================] - 10s 181ms/step - loss: 0.0362 - accuracy: 0.9855 - val_loss: 0.0093 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 73/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0231 - accuracy: 0.9919 - val_loss: 0.0141 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 74/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.0126 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 75/100
# 54/54 [==============================] - 10s 179ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.0194 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 76/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0168 - accuracy: 0.9959 - val_loss: 0.0109 - val_accuracy: 0.9932 - lr: 0.0010
# Epoch 77/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0140 - accuracy: 0.9948 - val_loss: 0.0821 - val_accuracy: 0.9681 - lr: 0.0010
# Epoch 78/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0491 - accuracy: 0.9844 - val_loss: 0.0115 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 79/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0271 - accuracy: 0.9913 - val_loss: 0.0070 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 80/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0075 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 81/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0209 - accuracy: 0.9948 - val_loss: 0.0088 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 82/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0069 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 83/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0023 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 84/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0089 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 85/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.0284 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 86/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0039 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 87/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.0059 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 88/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.0102 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 89/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0179 - accuracy: 0.9959 - val_loss: 6.6562e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 90/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 0.0256 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 91/100
# 54/54 [==============================] - 10s 180ms/step - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.0334 - val_accuracy: 0.9886 - lr: 0.0010
# Epoch 92/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0398 - accuracy: 0.9873 - val_loss: 0.0073 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 93/100
# 54/54 [==============================] - 10s 176ms/step - loss: 0.0262 - accuracy: 0.9942 - val_loss: 0.0032 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 94/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0130 - accuracy: 0.9965 - val_loss: 0.0268 - val_accuracy: 0.9954 - lr: 0.0010
# Epoch 95/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0097 - accuracy: 0.9971 - val_loss: 0.0070 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 96/100
# 54/54 [==============================] - 9s 175ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.0090 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 97/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0108 - accuracy: 0.9959 - val_loss: 0.0059 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 98/100
# 54/54 [==============================] - 10s 178ms/step - loss: 0.0244 - accuracy: 0.9931 - val_loss: 0.0117 - val_accuracy: 0.9977 - lr: 0.0010
# Epoch 99/100
# 54/54 [==============================] - 9s 176ms/step - loss: 0.0099 - accuracy: 0.9954 - val_loss: 0.0208 - val_accuracy: 0.9909 - lr: 0.0010
# Epoch 100/100
# 54/54 [==============================] - 10s 177ms/step - loss: 0.0253 - accuracy: 0.9925 - val_loss: 0.0109 - val_accuracy: 0.9954 - lr: 0.0010

# %%
print(model.summary())
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  conv2d_19 (Conv2D)          (None, 148, 148, 16)      448
#
#  max_pooling2d_19 (MaxPoolin  (None, 74, 74, 16)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 72, 72, 32)        4640
#
#  max_pooling2d_20 (MaxPoolin  (None, 36, 36, 32)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 34, 34, 64)        18496
#
#  max_pooling2d_21 (MaxPoolin  (None, 17, 17, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 15, 15, 128)       73856
#
#  max_pooling2d_22 (MaxPoolin  (None, 7, 7, 128)        0
#  g2D)
#
#  global_max_pooling2d_4 (Glo  (None, 128)              0
#  balMaxPooling2D)
#
#  flatten_5 (Flatten)         (None, 128)               0
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_10 (Dense)            (None, 512)               66048
#
#  dense_11 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 165,539
# Trainable params: 165,283
# Non-trainable params: 256
# _________________________________________________________________
# None

# %%
# TULIS CODE UNTUK PLOT EVALUASI MODEL DISINI
import matplotlib.pyplot as plt
def eval_plot(history):

  plt.figure(figsize=(14, 5))

  # Accuracy plot
  plt.subplot(1, 2, 1)
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  epochs = range(len(acc))
  acc_plot, = plt.plot(epochs, acc, 'r')
  val_acc_plot, = plt.plot(epochs, val_acc, 'b')
  plt.title('Training and Validation Accuracy')
  plt.legend([acc_plot, val_acc_plot], ['Training Accuracy', 'Validation Accuracy'])

  # Loss plot
  plt.subplot(1, 2, 2)
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(len(loss))
  loss_plot, = plt.plot(epochs, loss, 'r')
  val_loss_plot, = plt.plot(epochs, val_loss, 'b')
  plt.title('Training and Validation Loss')
  plt.legend([loss_plot, val_loss_plot], ['Training Loss', 'Validation Loss'])

# %%
eval_plot(history)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

def evaluate(model):

  valid_generator = train_generator.flow_from_directory(
          TRAIN_DIR, 
          target_size=(150,150), 
          batch_size=32, 
          class_mode='categorical',
          shuffle = False)

  batch_size = 32
  num_of_test_samples = len(valid_generator.filenames)

  Y_pred = model.predict_generator(valid_generator, num_of_test_samples // batch_size+1)
  y_pred = np.argmax(Y_pred, axis=1)

  print('\nConfusion Matrix\n')
  cm = confusion_matrix(valid_generator.classes, y_pred)
  plt.figure(figsize=(8, 8))
  sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Blues', cbar=False)
  plt.xticks(ticks=[0.5, 1.5, 2.5], labels=["Paper", "Rock", "Scissors"])
  plt.yticks(ticks=[0.5, 1.5, 2.5], labels=["Paper", "Rock", "Scissors"])
  plt.xlabel("Predicted")
  plt.ylabel("Actual")
  plt.title("Confusion Matrix")
  plt.show()

  print('\n\nClassification Report\n')
  target_names = ['Rock', 'Paper', 'Scissors']
  print(classification_report(valid_generator.classes, y_pred, target_names=target_names))

# %%
evaluate(model)

# %%
# TULIS CODE UNTUK PREDIKSI DATA TEST DISINI
import PIL

def predictModel(image_path):
    img = PIL.Image.open(image_path)
    img_resized = img.resize((150, 150), PIL.Image.LANCZOS)
    plt.imshow(img_resized)
    plt.axis('off')
    plt.title("First")
    img_array = np.expand_dims(np.array(img_resized), axis=0)

    predik = model.predict(img_array)

    labels = np.argmax(predik, axis=1)
    if labels == 0 :
      plt.title(f"Pred : {predik}\nLabels : {labels}kertas")
    elif labels == 1 :
      plt.title(f"Pred : {predik}\nLabels : {labels}batu")
    elif labels == 2 :
      plt.title(f"Pred : {predik}\nLabels : {labels}gunting")

# %%
import cv2
from matplotlib import pyplot as plt
  
fig = plt.figure(figsize=(25, 15))
  
rows = 3
columns = 5
  
fig.add_subplot(rows, columns, 1)
predictModel("/content/drive/MyDrive/PrakML/valid/paper/0a3UtNzl5Ll3sq8K.png")
fig.add_subplot(rows, columns, 2)
predictModel("/content/drive/MyDrive/PrakML/valid/paper/0zKU6wEhT2cDe9j0.png")
fig.add_subplot(rows, columns, 3)
predictModel("/content/drive/MyDrive/PrakML/valid/paper/2F8Ng7620ANA7tEK.png")
fig.add_subplot(rows, columns, 4)
predictModel("/content/drive/MyDrive/PrakML/valid/paper/4ZoU4nouZzb9G2MI.png")
fig.add_subplot(rows, columns, 5)
predictModel("/content/drive/MyDrive/PrakML/valid/paper/5NsmQol0TP7h80bh.png")

fig.add_subplot(rows, columns, 6)
predictModel("/content/drive/MyDrive/PrakML/valid/rock/00nKV8oHuTGi20gq.png")
fig.add_subplot(rows, columns, 7)
predictModel("/content/drive/MyDrive/PrakML/valid/rock/2f25VA1nfxiC86xj.png")
fig.add_subplot(rows, columns, 8)
predictModel("/content/drive/MyDrive/PrakML/valid/rock/1WuMUpzupKs67q29.png")
fig.add_subplot(rows, columns, 9)
predictModel("/content/drive/MyDrive/PrakML/valid/rock/3k7WrSAInCaatFtl.png")
fig.add_subplot(rows, columns, 10)
predictModel("/content/drive/MyDrive/PrakML/valid/rock/02vG75hQW9Vp4oTl.png")

fig.add_subplot(rows, columns, 11)
predictModel("/content/drive/MyDrive/PrakML/valid/scissors/0Flw60Z2MAWWKn6S.png")
fig.add_subplot(rows, columns, 12)
predictModel("/content/drive/MyDrive/PrakML/valid/scissors/0Ug54ifXRqqlZS2Z.png")
fig.add_subplot(rows, columns, 13)
predictModel("/content/drive/MyDrive/PrakML/valid/scissors/1MMkSW3f1CAsw03q.png")
fig.add_subplot(rows, columns, 14)
predictModel("/content/drive/MyDrive/PrakML/valid/scissors/VOgDVSfapx23t5tA.png")
fig.add_subplot(rows, columns, 15)
predictModel("/content/drive/MyDrive/PrakML/valid/scissors/UO03gubyPNMaJ8pj.png")

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file: json_file.write(model_json)

# %%
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Kegiatan 2 **(berkelompok)**
# 30 poin

# %% [markdown]
# **Ketentuan Wajib**
# * Tulis dokumentasi tugas kelompok anda dalam file README.md
# * Cek daftar dataset seluruh praktikan [disini](https://docs.google.com/spreadsheets/d/1qyu5AVDhPhegpRTbNaDoq5qXX4_CX09Q7tYyD-fkF_c/edit?usp=sharing)
# * Seluruh data dan progress pengerjaan tugas kelompok harus berada dalam github repository sebelum praktikum dimulai
# * Tidak diperbolehkan berganti anggota kelompok selama satu semester ini
# * Tidak diperbolehkan berganti repository selama mengerjakan tugas kelompok ini
# * **Tidak diperbolehkan berganti dataset atau jurnal rujukan**
# * Pastikan anda menggunakan akun github pribadi untuk melakukan commit dan push
#
# **Penilaian**
# * Keaktifan dalam tim
# * Kontribusi dalam proyek dan tim
# * Penerapan prinsip kerja Agile (sprint backlog dan report terdokumentasikan dengan baik)
# * Progress pengerjaan tugas kelompok
# * Pemahaman masing-masing anggota tim terhadap tugas yang dikerjakan
# * Pendokumentasian proyek "clear and clean documentation"
#
# **Materi pendukung**
# * [Project documentation](https://realpython.com/documenting-python-code)
# * [Github readme](https://docs.github.com/en/github/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax)
# * [Sprint backlog](https://www.lucidchart.com/blog/how-to-develop-a-product-backlog-in-agile)

# %% [markdown]
# **Tugas**
#
# Melanjutkan tugas kelompok di modul 1 & 2 sekarang kerjakan beberapa poin berikut untuk didemokan kepada asisten masing-masing.
#
# *   Melakukan proses preprocessing dataset dengan ketentuan:
#  * augmentasi data menggunakan ImageDataGenerator
#  * splitting dataset menjadi (75% train, 14% validation, 1% test)
# *   Melakukan training beberapa skema model menggunakan model CNN sederhana buatan sendiri **(minimal 2 model)** *tidak diperbolehkan menggunakan transfer learning*
#  * Menerapkan proses Convolution
#  * Menerapkan proses Pooling
#  * Menerapkan Dropout
#  * Menerpakan BatchNormalization
#  * Model dengan beberapa variasi learning rate
#  * Minimal 100 epoch per model
# * Menyimpan model yang telah di training kedalam file `.h5` [Lihat disini](https://www.tensorflow.org/tutorials/keras/save_and_load)
# *  Mencatat hasil perkembangan tugas kelompok dalam file `sprint_project.xlsx` tandai masing-masing task dengan status **Done** *untuk task yang telah selesai dikerjakan*, **On Going** *untuk task yang dalam proses pengerjaan*, **Waiting** *untuk task yang belum atau akan dikerjakan*
# * Pastikan anda menulis tanggal mulai dan tanggal selesai masing-masing task dengan benar
# * Pastikan anda menulis penanggung jawab masing-masing task (Penanggung jawab bertugas menyelesaikan dan menuntaskan masing-masing task yang diberikan)
# * `commit` dan `push` seluruh perkerjaan yang anda lakukan kedalam branch pribadi dalam repository tugas kelompok yang telah anda buat sebelumnya.
# * Presentasikan kepada asisten tentang apa yang anda lakukakan selama mengerjakan tugas kelompok ini. Ceritakan tentang tugas masing-masing anggota,  kendala dalam mengerjakan tugas sampai solusi yang anda lakukan saat mengerjakan tugas kelompok ini.
